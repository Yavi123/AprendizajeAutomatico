# %%
from multi_linear_reg import zscore_normalize_features
from multi_linear_reg import compute_cost
from multi_linear_reg import compute_gradient
from multi_linear_reg import gradient_descent

from public_tests import test_data
from public_tests import compute_cost_test
from public_tests import compute_gradient_test
from public_tests import sklearn_linearmodel

from utils import load_data_multi
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x, y = load_data_multi()

# Gráfico 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:, 0], x[:, 2], y)
ax.set_xlabel('Size')
ax.set_ylabel('Num of floors')
ax.set_zlabel('Price')
ax.set_title('Houses')

plt.show()

# Gráfico 2D
plt.scatter(x[:, 1], x[:, 3])
plt.xlabel('NumRooms')
plt.ylabel('Antiquity')
plt.title('NumRooms / Antiquity')

plt.show()


########### TEST ##########

# Test de la funcion de coste
#compute_cost_test(compute_cost)
#X_norm, mu, sigma = zscore_normalize_features()


# Test de la funcion de coste
compute_cost_test(compute_cost)
# Test de la funcion de gradiente
compute_gradient_test(compute_gradient)
# Test de la funcion de descenso de gradiente
#w, b, Jhistory = gradient_descent(X, y, 0, 0, compute_cost, compute_gradient, 0.01, 1500)
#compute_gradient_descent_test(w, b)



## Dibuja la recta de regresion con la pendiente (w) y la constante (b) para todos los valores de X especificados
#def drawRegresionRect(w, b, Xvalues):
#    # Calcular los puntos dentro dentro de la linea de regresion para poder pintarla
#    y_rectValue = w * x_rectValue + b; # para cada uno de esos valores de X, calcular la Y en la recta
#    # Pintar la recta de rojo
#    plt.plot(x_rectValue, y_rectValue, color='red', label='Recta de Regresión')
#    # Mostrar cuadricula
#    plt.grid(True)
#    plt.show()
#
#
#
########### DIBUJAR DATOS INICIALES ##########
#
## Cargar los puntos
#x, y = load_data()
## Dibujar los puntos de los datos
#plt.scatter(x, y, marker='o', color='blue', label='Puntos')
#plt.title('Puntos de los datos')
#plt.show()
#
#
########### TEST ##########
#
## Test de la funcion de coste
#compute_cost_test(compute_cost)
## Test de la funcion de gradiente
#compute_gradient_test(compute_gradient)
## Test de la funcion de descenso de gradiente
#w, b, Jhistory = gradient_descent(X, y, 0, 0, compute_cost, compute_gradient, 0.01, 1500)
#compute_gradient_descent_test(w, b)
#
#
########### DIBUJAR DATOS FINALES ##########
#
## Array con todas las iteraciones, usada para representar los graficos
#iterations = np.arange(1, 1500 + 1)
#
## Dibujar el historial de costes a lo largo de la funcion de descenso de gradiente
#plt.plot(iterations, Jhistory, color='blue')
#plt.title('Historial de costes - COSTE/ITERACION')
#plt.show();
#
## Dibujar los puntos de los datos
#plt.scatter(x, y, marker='o', color='blue', label='Puntos')
#plt.title('Recta de regresion - Usando el Descenso de gradiente')
## Dibujar la recta de regresion basada en los datos mejorados con la funcion de descenso de gradiente
#drawRegresionRect(w, b, x_minMax)
# Out:
# All tests passed!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 47
#      45 compute_cost_test(compute_cost)
#      46 # Test de la funcion de gradiente
# ---> 47 compute_gradient_test(compute_gradient)
#
# File ~\Videos\AprendizajeAutomatico\Practica2\public_tests.py:34, in compute_gradient_test(target)
#      31 target_dj_db = -1.6739251122999121e-06
#      32 target_dj_dw = [-2.73e-3, - 6.27e-6, - 2.22e-6, - 6.92e-5]
# ---> 34 assert np.isclose(dj_db, target_dj_db,
#      35                   rtol=1e-4), f"Case 1: dj_db is wrong: {dj_db} != {target_dj_db}"
#      36 assert np.allclose(
#      37     dj_dw, target_dj_dw, rtol=1e-02), f"Case 1: dj_dw is wrong: {dj_dw} != {target_dj_dw}"
#      39 print("\033All tests passed!")
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
